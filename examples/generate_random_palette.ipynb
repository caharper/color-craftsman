# %%
import color_craftsman as cc

# %% [markdown]
# # Generate a Random Palette
#
# Here, we just generate a random palette of colors. We can use this to generate a random color palette for a plot, or to generate a random color palette for a website. We specify the minimum distance between colors where a larger value means the colors will be more distinct. We also specify the number of colors to generate.

# %%
palette = cc.generate_palette(
    5,
    min_dist=30,
    seed=11,
    output_format="rgb",
)
cc.visualize_palette(palette, show=True)

# %% [markdown]
# # Extending a Palette
#
# If you already have a base color or a base palette, you can extend it to generate a larger palette, containing the original colors.

# %%
new_palette = cc.extend_palette(
    palette,
    10,
    min_dist=10,
    seed=18,
    palette_format="rgb",
    output_format="rgb",
)
cc.visualize_palette(new_palette, show=True)

# %% [markdown]
# # Colorblind-Safe Palettes
#
# We can generate colorblind-safe palettes using the `colorblind_safe` argument. The drawback is that there are fewer colors to choose from. Setting `colorblind_safe` to `True` will generate a colorblind-safe palette for 3 types of colorblindness. This guards against deuteranopia, protanopia, and tritanopia.

# %%
palette = cc.generate_palette(
    5,
    min_dist=30,
    seed=22,
    output_format="rgb",
    colorblind_safe=True,
)
cc.visualize_palette(palette, show=True)

# %% [markdown]
# ## Specific Colorblind-Safe Palettes
#
# If you want to guard against specific-forms of colorblindness, you can specify the type of colorblindness using the following arguments: `deuteranomaly_safe`, `protanomaly_safe`, and `tritanomaly_safe`.

# %% [markdown]
# ### Deuteranomaly-Safe Palettes

# %%
palette = cc.generate_palette(
    5,
    min_dist=30,
    seed=33,
    output_format="rgb",
    deuteranomaly_safe=True,
)
cc.visualize_palette(palette)

# %% [markdown]
# ### Protanomaly-Safe Palettes

# %%
palette = cc.generate_palette(
    5,
    min_dist=30,
    seed=44,
    output_format="rgb",
    protanomaly_safe=True,
)
cc.visualize_palette(palette)

# %% [markdown]
# ### Tritanomaly-Safe Palettes

# %%
palette = cc.generate_palette(
    5,
    min_dist=30,
    seed=55,
    output_format="rgb",
    tritanomaly_safe=True,
)
cc.visualize_palette(palette)
